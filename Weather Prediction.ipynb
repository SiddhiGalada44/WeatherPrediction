# %%
import pandas as pd
weather=pd.read_csv("weather.csv",index_col="DATE")

# %%
weather
# Out:
#                 STATION                                      NAME  ACMH  ACSH  \
# DATE
# 1970-01-01  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  10.0
# 1970-01-02  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0   0.0
# 1970-01-03  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  60.0  60.0
# 1970-01-04  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  20.0   0.0
# 1970-01-05  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  30.0  60.0
# ...                 ...                                       ...   ...   ...
# 2024-11-09  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-11-10  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-11-11  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-11-12  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2024-11-13  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
# ...

# %%
null_pct=weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.505015
# ACSH       0.504965
# AWND       0.255476
# FMTM       0.697171
# PGTM       0.267452
# PRCP       0.000050
# SNOW       0.498927
# SNWD       0.465546
# TAVG       0.655207
# TMAX       0.000050
# TMIN       0.000050
# TSUN       0.942568
# WDF1       0.977147
# WDF2       0.483459
# WDF5       0.503867
# WDFG       0.507260
# WDFI       0.940272
# WDFM       0.999701
# WESD       0.708398
# WSF1       0.977147
# WSF2       0.483459
# WSF5       0.503867
# WSFG       0.507061
# WSFI       0.940272
# WSFM       0.999701
# WT01       0.627563
# WT02       0.939773
# WT03       0.988374
# WT04       0.999701
# WT05       0.993813
# WT06       0.999950
# WT07       0.982087
# WT08       0.514445
# WT09       0.996258
# WT10       0.999850
# WT11       0.999900
# WT13       0.851904
# WT14       0.983883
# WT16       0.881243
# WT18       0.999950
# WT21       0.995110
# WV01       0.998802
# WV03       0.999900
# ...

# %%
valid_columns=weather.columns[null_pct<.05]
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'TMAX', 'TMIN'], dtype='object')

# %%
weather=weather[valid_columns].copy()

# %%
weather.columns=weather.columns.str.lower()

# %%
weather
# Out:
#                 station                                      name  prcp  tmax  \
# DATE
# 1970-01-01  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  62.0
# 1970-01-02  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-03  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-04  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  60.0
# 1970-01-05  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# ...                 ...                                       ...   ...   ...
# 2024-11-09  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  72.0
# 2024-11-10  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-11  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  66.0
# 2024-11-12  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-13  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
#             tmin
# DATE
# ...

# %%
weather=weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2024-11-04', '2024-11-05', '2024-11-06', '2024-11-07', '2024-11-08',
#        '2024-11-09', '2024-11-10', '2024-11-11', '2024-11-12', '2024-11-13'],
#       dtype='object', name='DATE', length=20041)

# %%
weather.index=pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2024-11-04', '2024-11-05', '2024-11-06', '2024-11-07',
#                '2024-11-08', '2024-11-09', '2024-11-10', '2024-11-11',
#                '2024-11-12', '2024-11-13'],
#               dtype='datetime64[ns]', name='DATE', length=20041, freq=None)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    318
# Name: count, dtype: int64

# %%
weather["prcp"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                                      name  prcp  tmax  \
# DATE
# 1970-01-01  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  62.0
# 1970-01-02  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-03  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-04  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  60.0
# 1970-01-05  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# ...                 ...                                       ...   ...   ...
# 2024-11-09  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  72.0
# 2024-11-10  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-11  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  66.0
# 2024-11-12  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-13  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0   0.0
#
#             tmin
# DATE
# ...

# %%
weather["target"]=weather.shift(-1)["tmax"]
weather
# Out:
#                 station                                      name  prcp  tmax  \
# DATE
# 1970-01-01  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  62.0
# 1970-01-02  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-03  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-04  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  60.0
# 1970-01-05  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# ...                 ...                                       ...   ...   ...
# 2024-11-09  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  72.0
# 2024-11-10  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-11  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  66.0
# 2024-11-12  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-13  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0   0.0
#
#             tmin  target
# ...

# %%
weather=weather.ffill()

# %%
weather
# Out:
#                 station                                      name  prcp  tmax  \
# DATE
# 1970-01-01  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  62.0
# 1970-01-02  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-03  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-04  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  60.0
# 1970-01-05  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# ...                 ...                                       ...   ...   ...
# 2024-11-09  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  72.0
# 2024-11-10  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-11  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  66.0
# 2024-11-12  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-13  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0   0.0
#
#             tmin  target
# ...

# %%
from sklearn.linear_model import Ridge
rr=Ridge(alpha=.1)

# %%
weather.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-7abb8bc3d4be> in <cell line: 1>()
# ----> 1 weather.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
weather.corr(numeric_only=True)
# Out:
#             prcp      tmax      tmin    target
# prcp    1.000000 -0.236909 -0.106397 -0.214960
# tmax   -0.236909  1.000000  0.637461  0.798466
# tmin   -0.106397  0.637461  1.000000  0.574599
# target -0.214960  0.798466  0.574599  1.000000

# %%
predictors=weather.columns[~weather.columns.isin(["target","station","name"])]
predictors
# Out:
# Index(['prcp', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather,model,predictors,start=3650,step=90):
  all_predictions=[]
  for i in range(start,weather.shape[0],step):
    train=weather.iloc[:i,:]
    test=weather.iloc[i:(i+step),:]
    model.fit(train[predictors],train["target"])
    preds=model.predict(test[predictors])
    preds=pd.Series(preds,index=test.index)
    combined=pd.concat([test["target"],preds],axis=1)
    combined.columns=["actual","prediction"]
    combined["diff"]=(combined["actual"]-combined["prediction"]).abs()
    all_predictions.append(combined)
  return pd.concat(all_predictions)

# %%
predictions=backtest(weather,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    68.0   67.261752   0.738248
# 1979-12-31    71.0   68.228399   2.771601
# 1980-01-01    79.0   70.648942   8.351058
# 1980-01-02    78.0   75.985132   2.014868
# 1980-01-03    72.0   75.857429   3.857429
# ...            ...         ...        ...
# 2024-11-09    71.0   70.736881   0.263119
# 2024-11-10    66.0   70.138501   4.138501
# 2024-11-11    71.0   66.296954   4.703046
# 2024-11-12     0.0   70.866771  70.866771
# 2024-11-13     0.0   12.966752  12.966752
#
# [16391 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 3.081919088545079

# %%
predictions["diff"].mean()
# Out:
# 3.081919088545079

# %%
def pct_diff(old,new):
  return (new-old)/old

def compute_rolling(weather,horizon,col):
  label=f"rolling_{horizon}_{col}"
  weather[label]=weather[col].rolling(horizon).mean()
  weather[f"{label}_pct"]=pct_diff(weather[label],weather[col])
  return weather

rolling_horizons=[3,14]

for horizon in rolling_horizons:
  for col in ["tmax","tmin","prcp"]:
    weather=compute_rolling(weather,horizon,col)

# %%
weather
# Out:
#                 station                                      name  prcp  tmax  \
# DATE
# 1970-01-01  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  62.0
# 1970-01-02  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-03  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# 1970-01-04  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  60.0
# 1970-01-05  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  65.0
# ...                 ...                                       ...   ...   ...
# 2024-11-09  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  72.0
# 2024-11-10  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-11  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  66.0
# 2024-11-12  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 2024-11-13  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0   0.0
#
# ...

# %%
weather=weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                                      name  prcp  tmax  \
# DATE
# 1970-01-15  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.05  61.0
# 1970-01-16  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.67  60.0
# 1970-01-17  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  64.0
# 1970-01-18  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  63.0
# 1970-01-19  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  63.0
# ...                 ...                                       ...   ...   ...
# 2024-11-09  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  72.0
# 2024-11-10  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  71.0
# 2024-11-11  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  66.0
# 2024-11-12  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  71.0
# 2024-11-13  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00   0.0
#
# ...

# %%
weather=weather.fillna(0)

# %%
def expand_mean(df):
  return df.expanding(1).mean()
for col in["tmax","tmin","prcp"]:
    weather[f"{col}_mean"]=weather[col].groupby(weather.index.month,group_keys=False).apply(expand_mean)
    weather[f"{col}_mean"]=weather[col].groupby(weather.index.day_of_year,group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                                      name  prcp  tmax  \
# DATE
# 1970-01-15  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.05  61.0
# 1970-01-16  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.67  60.0
# 1970-01-17  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  64.0
# 1970-01-18  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  63.0
# 1970-01-19  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  63.0
# ...                 ...                                       ...   ...   ...
# 2024-11-09  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  72.0
# 2024-11-10  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  71.0
# 2024-11-11  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  66.0
# 2024-11-12  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00  71.0
# 2024-11-13  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  0.00   0.0
#
# ...

# %%
predictors=weather.columns[~weather.columns.isin(["target","station","name"])]
predictors
# Out:
# Index(['prcp', 'tmax', 'tmin', 'rolling_3_tmax', 'rolling_3_tmax_pct',
#        'rolling_3_tmin', 'rolling_3_tmin_pct', 'rolling_3_prcp',
#        'rolling_3_prcp_pct', 'rolling_14_tmax', 'rolling_14_tmax_pct',
#        'rolling_14_tmin', 'rolling_14_tmin_pct', 'rolling_14_prcp',
#        'rolling_14_prcp_pct', 'tmax_mean', 'tmin_mean', 'prcp_mean'],
#       dtype='object')

# %%
predictions=backtest(weather,rr,predictors)

# %%
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 3.022864541486131

# %%
predictions.sort_values("diff",ascending=False).head(10)
# Out:
#             actual  prediction       diff
# DATE
# 2024-11-12     0.0   70.517688  70.517688
# 2002-02-20    89.0   63.169472  25.830528
# 1989-04-03    99.0   73.959390  25.040610
# 2004-09-04   101.0   77.324982  23.675018
# 1988-09-03   106.0   82.390817  23.609183
# 2021-11-20    88.0   64.917579  23.082421
# 2022-04-06    95.0   72.488034  22.511966
# 2010-09-26   105.0   82.548963  22.451037
# 1996-04-28    94.0   71.713152  22.286848
# 2024-11-13     0.0   22.279213  22.279213

# %%
weather.loc["1996-04-23":"1996-04-28"]
# Out:
#                 station                                      name  prcp  tmax  \
# DATE
# 1996-04-23  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  78.0
# 1996-04-24  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  75.0
# 1996-04-25  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  74.0
# 1996-04-26  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 1996-04-27  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  71.0
# 1996-04-28  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US   0.0  72.0
#
#             tmin  target  rolling_3_tmax  rolling_3_tmax_pct  rolling_3_tmin  \
# DATE
# 1996-04-23  56.0    75.0       73.000000            0.068493       53.666667
# 1996-04-24  59.0    74.0       75.333333           -0.004425       56.000000
# 1996-04-25  59.0    71.0       75.666667           -0.022026       58.000000
# 1996-04-26  60.0    71.0       73.333333           -0.031818       59.333333
# ...

# %%
(predictions["diff"]).round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>
